# %% [markdown]
# # COVID

# %% [markdown]
# Referencia: https://pypi.org/project/covid-data-api/
#
# En función a la documentación de referencia se trabajó con los datos de Covid para generar información que pueda ser de relevancia.

# %%
import json
import pandas as pd

# %%
from covid.api import CovId19Data
api = CovId19Data(force=False)

# %%
pip install covid-data-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: covid-data-api in /usr/local/lib/python3.9/dist-packages (1.5)
# Requirement already satisfied: python-dateutil==2.8.1 in /usr/local/lib/python3.9/dist-packages (from covid-data-api) (2.8.1)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.9/dist-packages (from covid-data-api) (2.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil==2.8.1->covid-data-api) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests==2.23.0->covid-data-api) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests==2.23.0->covid-data-api) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests==2.23.0->covid-data-api) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests==2.23.0->covid-data-api) (2.10)

# %%
res = api.get_stats()

# %%
# Vemos la info total
res
# Out:
# {'confirmed': 676570149,
#  'recovered': 0,
#  'deaths': 6881802,
#  'last_updated': '2023-03-09 00:00:00'}

# %%
# Filtramos usando la Key Argentina
res = api.filter_by_country("argentina")

# %%
# Vemos los datos totales de Argentina
res
# Out:
# {'confirmed': 10044957,
#  'label': 'Argentina',
#  'last_updated': '2023-03-09 00:00:00',
#  'lat': '-38.4161',
#  'long': '-63.6167',
#  'recovered': 0,
#  'deaths': 130472}

# %%
# Consultamos los resultados por pais
res = api.get_all_records_by_country()

# %%
# Generarmos en Dataset
covid = pd.DataFrame(res)

# %%
#Transponemos
covid = covid.T

# %%
#Mostramos el Dataset
covid
# Out:
#                      confirmed                 label         last_updated  \
# afghanistan             209451           Afghanistan  2023-03-09 00:00:00
# albania                 334457               Albania  2023-03-09 00:00:00
# algeria                 271496               Algeria  2023-03-09 00:00:00
# andorra                  47890               Andorra  2023-03-09 00:00:00
# angola                  105288                Angola  2023-03-09 00:00:00
# ...                        ...                   ...                  ...
# west_bank_and_gaza      703228    West Bank and Gaza  2023-03-09 00:00:00
# winter_olympics_2022       535  Winter Olympics 2022  2023-03-09 00:00:00
# yemen                    11945                 Yemen  2023-03-09 00:00:00
# zambia                  343135                Zambia  2023-03-09 00:00:00
# zimbabwe                264276              Zimbabwe  2023-03-09 00:00:00
#
#                              lat       long recovered deaths
# afghanistan             33.93911  67.709953         0   7896
# albania                  41.1533    20.1683         0   3598
# algeria                  28.0339     1.6596         0   6881
# andorra                  42.5063     1.5218         0    165
# angola                  -11.2027    17.8739         0   1933
# ...                          ...        ...       ...    ...
# west_bank_and_gaza       31.9522    35.2332         0   5708
# winter_olympics_2022     39.9042   116.4074         0      0
# yemen                  15.552727  48.516388         0   2159
# zambia                -13.133897  27.849332         0   4057
# zimbabwe              -19.015438  29.154857         0   5671
#
# [201 rows x 7 columns]

# %%
# Consultamos el dataset por Ciudades/Provincias
provincias = api.get_all_records_by_provinces()

# %%
# Generamos el Dataset
covid_prov = pd.DataFrame(provincias)

# %%
# Transponemos
covid_prov = covid_prov.T

# %%
# Mostramos el dataset
covid_prov
# Out:
#                                             confirmed  \
# australian_capital_territory                   232974
# new_south_wales                               3915992
# northern_territory                             105111
# queensland                                    1800236
# south_australia                                883620
# ...                                               ...
# jersey                                          66391
# montserrat                                       1403
# pitcairn_islands                                    4
# saint_helena_ascension_and_tristan_da_cunha      2166
# turks_and_caicos_islands                         6561
#
#                                                                                     label  \
# australian_capital_territory                                 Australian Capital Territory
# new_south_wales                                                           New South Wales
# northern_territory                                                     Northern Territory
# queensland                                                                     Queensland
# south_australia                                                           South Australia
# ...                                                                                   ...
# jersey                                                                             Jersey
# montserrat                                                                     Montserrat
# pitcairn_islands                                                         Pitcairn Islands
# saint_helena_ascension_and_tristan_da_cunha  Saint Helena, Ascension and Tristan da Cunha
# turks_and_caicos_islands                                         Turks and Caicos Islands
#
#                                                     country        lat  \
# australian_capital_territory                      Australia   -35.4735
# new_south_wales                                   Australia   -33.8688
# northern_territory                                Australia   -12.4634
# queensland                                        Australia   -27.4698
# south_australia                                   Australia   -34.9285
# ...                                                     ...        ...
# jersey                                       United Kingdom    49.2138
# montserrat                                   United Kingdom  16.742498
# pitcairn_islands                             United Kingdom   -24.3768
# saint_helena_ascension_and_tristan_da_cunha  United Kingdom    -7.9467
# turks_and_caicos_islands                     United Kingdom     21.694
#
#                                                    long         last_updated  \
# australian_capital_territory                   149.0124  2023-03-09 00:00:00
# new_south_wales                                151.2093  2023-03-09 00:00:00
# northern_territory                             130.8456  2023-03-09 00:00:00
# queensland                                     153.0251  2023-03-09 00:00:00
# south_australia                                138.6007  2023-03-09 00:00:00
# ...                                                 ...                  ...
# jersey                                          -2.1358  2023-03-09 00:00:00
# montserrat                                   -62.187366  2023-03-09 00:00:00
# pitcairn_islands                              -128.3242  2023-03-09 00:00:00
# saint_helena_ascension_and_tristan_da_cunha    -14.3559  2023-03-09 00:00:00
# turks_and_caicos_islands                       -71.7979  2023-03-09 00:00:00
#
#                                             recovered deaths
# australian_capital_territory                        0    228
# new_south_wales                                     0   6529
# northern_territory                                  0     91
# queensland                                          0   2783
# south_australia                                     0   1365
# ...                                               ...    ...
# jersey                                              0    161
# montserrat                                          0      8
# pitcairn_islands                                    0      0
# saint_helena_ascension_and_tristan_da_cunha         0      0
# turks_and_caicos_islands                            0     38
#
# [91 rows x 8 columns]

# %%
# Consultamos los primeros 10 paises de la lista
paises = api.show_available_countries()
paises[0:10]
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antarctica',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia']

# %%
# Consultamos la cantidad total de paises

len(paises)
# Out:
# 201

# %%
# Consultamos el historial de Argentina
arg = api.get_history_by_country('argentina')

# Convertimos con dumps
arg_tx=json.dumps(arg)

# Convertirmos en json
arg_json=json.loads(arg_tx)

# Verificamos la Key
arg_json.keys()
# Out:
# dict_keys(['argentina'])

# %%
# Consultamos las subclaves 
for clave in arg_json.keys():
    print(f"Clave: {clave}")
    valor = arg_json[clave]

    if isinstance(valor, dict):
        print("Subclaves:")
        for subclave in valor.keys():
            print(f"- {subclave}")
# Out:
# Clave: argentina
# Subclaves:
# - label
# - lat
# - long
# - history

# %%
# Consultamos la Subclave History, que es la que contiene los datos que nos interesan
arg_evo = arg_json['argentina']['history']

# %%
# Generamos el dataset con la información histórica.
arg_df =pd.DataFrame.from_dict(arg_evo)

#Transponemos
arg_df=arg_df.T

# Mostramos el Dataset de Argentina
arg_df
# Out:
#                     confirmed       change_confirmed recovered  \
# 2020-01-22 00:00:00         0                     na         0
# 2020-01-23 00:00:00         0                     na         0
# 2020-01-24 00:00:00         0                     na         0
# 2020-01-25 00:00:00         0                     na         0
# 2020-01-26 00:00:00         0                     na         0
# ...                       ...                    ...       ...
# 2023-03-05 00:00:00  10044125                    0.0         0
# 2023-03-06 00:00:00  10044957  8.283449280051772e-05         0
# 2023-03-07 00:00:00  10044957                    0.0         0
# 2023-03-08 00:00:00  10044957                    0.0         0
# 2023-03-09 00:00:00  10044957                    0.0         0
#
#                     change_recovered  deaths          change_deaths
# 2020-01-22 00:00:00               na       0                     na
# 2020-01-23 00:00:00               na       0                     na
# 2020-01-24 00:00:00               na       0                     na
# 2020-01-25 00:00:00               na       0                     na
# 2020-01-26 00:00:00               na       0                     na
# ...                              ...     ...                    ...
# 2023-03-05 00:00:00               na  130463                    0.0
# 2023-03-06 00:00:00               na  130472  6.898507622850923e-05
# 2023-03-07 00:00:00               na  130472                    0.0
# 2023-03-08 00:00:00               na  130472                    0.0
# 2023-03-09 00:00:00               na  130472                    0.0
#
# [1143 rows x 6 columns]

# %%
# Repetimos los pasos para objetener la información histórica de China

china = api.get_history_by_country('china')
china_tx=json.dumps(china)
china_json=json.loads(china_tx)

# %%
# Consultamos la Subclave History, que es la que contiene los datos que nos interesan

china_evo = china_json['china']['history']

# %%
# Generamos el Dataset, transponemos y lo mostramos.

china_df =pd.DataFrame.from_dict(china_evo)
china_df=china_df.T
china_df
# Out:
#                     confirmed    change_confirmed recovered change_recovered  \
# 2020-01-22 00:00:00       548                  na        28               na
# 2020-01-23 00:00:00       643                 1.7        30               na
# 2020-01-24 00:00:00       920  0.5925925925925926        36               na
# 2020-01-25 00:00:00      1406  0.4418604651162791        39              0.0
# 2020-01-26 00:00:00      2075  0.6774193548387096        49              0.0
# ...                       ...                 ...       ...              ...
# 2023-03-05 00:00:00   4903524                 0.0         0               na
# 2023-03-06 00:00:00   4903524                 0.0         0               na
# 2023-03-07 00:00:00   4903524                 0.0         0               na
# 2023-03-08 00:00:00   4903524                 0.0         0               na
# 2023-03-09 00:00:00   4903524                 0.0         0               na
#
#                      deaths change_deaths
# 2020-01-22 00:00:00      17            na
# 2020-01-23 00:00:00      18            na
# 2020-01-24 00:00:00      26            na
# 2020-01-25 00:00:00      42            na
# 2020-01-26 00:00:00      56            na
# ...                     ...           ...
# 2023-03-05 00:00:00  101054           0.0
# 2023-03-06 00:00:00  101055           0.0
# 2023-03-07 00:00:00  101055           0.0
# 2023-03-08 00:00:00  101055           0.0
# 2023-03-09 00:00:00  101056           0.0
#
# [1143 rows x 6 columns]

# %%
# Generamos el nombre del pais
arg_df['nombre_pais'] = 'Argentina'
china_df['nombre_pais'] = 'China'

# Unimos los dos Dataset
arg_china_df = pd.concat([arg_df, china_df])

#Mostramos el Dataset con los casos de Argentina y China
arg_china_df
# Out:
#                     confirmed change_confirmed recovered change_recovered  \
# 2020-01-22 00:00:00         0               na         0               na
# 2020-01-23 00:00:00         0               na         0               na
# 2020-01-24 00:00:00         0               na         0               na
# 2020-01-25 00:00:00         0               na         0               na
# 2020-01-26 00:00:00         0               na         0               na
# ...                       ...              ...       ...              ...
# 2023-03-05 00:00:00   4903524              0.0         0               na
# 2023-03-06 00:00:00   4903524              0.0         0               na
# 2023-03-07 00:00:00   4903524              0.0         0               na
# 2023-03-08 00:00:00   4903524              0.0         0               na
# 2023-03-09 00:00:00   4903524              0.0         0               na
#
#                      deaths change_deaths nombre_pais
# 2020-01-22 00:00:00       0            na   Argentina
# 2020-01-23 00:00:00       0            na   Argentina
# 2020-01-24 00:00:00       0            na   Argentina
# 2020-01-25 00:00:00       0            na   Argentina
# 2020-01-26 00:00:00       0            na   Argentina
# ...                     ...           ...         ...
# 2023-03-05 00:00:00  101054           0.0       China
# 2023-03-06 00:00:00  101055           0.0       China
# 2023-03-07 00:00:00  101055           0.0       China
# 2023-03-08 00:00:00  101055           0.0       China
# 2023-03-09 00:00:00  101056           0.0       China
#
# [2286 rows x 7 columns]

# %% [markdown]
# # CANALES DE YOUTUBE

# %%
#importo las librerias
import requests
import json
import pandas as pd

# %%
# defino la apikey de youtube
api_key='AIzaSyBlDq160tEZKUz8h0mSgdyiV7aeeKg5ggig'

# %%
# Instalo librerias
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.9/dist-packages (2.70.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (2.16.2)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.19.6)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.58.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.25.11)

# %%
# Me conecto
from googleapiclient.discovery import build
api_key='AIzaSyBlDq160tEZKUz8h0mSgdyiV7aeeKg5ggig' 
youtube_claudio= build('youtube','v3',developerKey=api_key)

# %%
# Hago el request del canal 1 para traer el nombre
request=youtube_claudio.channels().list(
    part='snippet',
    forUsername= 'PersonalArgentina'
)
response=request.execute()
sna = response['items'][0]['snippet']['title']

# %%
# Hago el request del canal 1 traer la estadistica
request=youtube_claudio.channels().list(
    part='statistics',
    forUsername= 'PersonalArgentina' 
)
response=request.execute()
id = response['items'][0]['id']
stats = response['items'][0]['statistics']

# %%
# organizo y creo el dataframe del canal 1
canal1 = {
    'canal_id': id,
    'titulo': sna,
    'vistas': stats['viewCount'],
    'suscriptores': stats['subscriberCount'],
    'videos': stats['videoCount']
}
canal1_df = pd.DataFrame([canal1])

# %%
# Hago el request del canal 2 para traer el nombre
request=youtube_claudio.channels().list(
    part='snippet',
    forUsername= 'GrupoTelecom' 
)
response=request.execute()
sna = response['items'][0]['snippet']['title']

# %%
# Hago el request del canal 2 traer la estadistica
request=youtube_claudio.channels().list(
    part='statistics',
    forUsername= 'GrupoTelecom' 
)
response=request.execute()
id = response['items'][0]['id']
stats = response['items'][0]['statistics']

# %%
# organizo y creo el dataframe del canal 2
canal2 = {
    'titulo': sna,
    'canal_id': id,
    'vistas': stats['viewCount'],
    'suscriptores': stats['subscriberCount'],
    'videos': stats['videoCount']
}
canal2_df = pd.DataFrame([canal2])

# %%
# Hago el request del canal 3 para traer el nombre
request=youtube_claudio.channels().list(
    part='snippet',
    forUsername= 'FlowMusic' 
)
response=request.execute()
sna = response['items'][0]['snippet']['title']

# %%
# Hago el request del canal 3 traer la estadistica
request=youtube_claudio.channels().list(
    part='statistics',
    forUsername= 'FlowMusic' 
)
response=request.execute()
id = response['items'][0]['id']
stats = response['items'][0]['statistics']

# %%
# organizo y creo el dataframe del canal 3
canal3 = {
    'canal_id': id,
    'titulo': sna,
    'vistas': stats['viewCount'],
    'suscriptores': stats['subscriberCount'],
    'videos': stats['videoCount']
}
canal3_df = pd.DataFrame([canal3])

# %%
# Concatenamos en un unico Dataframe
canales_df = pd.concat([canal1_df, canal2_df, canal3_df], ignore_index=True)

# %%
# Mostramos el Dataframe
canales_df
# Out:
#                    canal_id              titulo    vistas suscriptores videos
# 0  UCXDcLKPcgi6b_c3G_aUNdPA  Personal Argentina  26228862       110000     18
# 1  UC5KvQ3VB3pC96lAF4aLI9bw   Telecom Argentina     64075         2330    107
# 2  UC87qPnuuMBXA2-rx5JKrqYA           Flowmusic   5065861          905     18
